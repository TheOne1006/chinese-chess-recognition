# %%
import sys

onnx_target_dir = '/home/theone/my-programes/det-chinese-chesss/datasets'
sys.path.append(f'{onnx_target_dir}/onnxcore')

from runonnx.full_classifier import FULL_CLASSIFIER_ONNX

# %%
# !pwd
# Out:
# /home/theone/my-programes/chinese-chess-recognition/cchess_reg/examples

# %%
full_classifier = FULL_CLASSIFIER_ONNX(
    model_path="/home/theone/my-programes/chinese-chess-recognition/cchess_reg/work_dirs/deploy/cchess_reg.onnx",
    enable_cuda=False
    )

# %%
img_path = "/home/theone/my-programes/chinese-chess-recognition/cchess_reg/data/cchess_multi_label_layout/val/20250219_qilu_val_250218123200.jpg"
_, short_labels, confidence_10x9, _ = full_classifier.pred(img_path)

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.cvtColor(cv2.imread(img_path), cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.show()

# %%
short_labels
# Out:
# [['.', '.', '.', '.', 'k', 'a', 'b', '.', '.'],
#  ['.', '.', '.', '.', 'a', '.', '.', '.', '.'],
#  ['.', '.', '.', 'n', 'b', '.', '.', '.', '.'],
#  ['.', '.', '.', '.', 'r', '.', '.', '.', '.'],
#  ['.', '.', '.', '.', '.', '.', 'P', 'C', 'P'],
#  ['p', '.', 'B', 'n', '.', '.', '.', '.', '.'],
#  ['.', 'R', '.', '.', '.', '.', 'C', '.', '.'],
#  ['.', '.', '.', '.', 'B', '.', '.', '.', '.'],
#  ['.', '.', '.', '.', 'A', '.', '.', '.', '.'],
#  ['.', '.', '.', '.', 'K', 'A', '.', '.', '.']]
